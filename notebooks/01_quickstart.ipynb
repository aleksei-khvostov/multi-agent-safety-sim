# %% [markdown]
# # Quickstart — multi_agent_safety_sim
#
# This notebook demonstrates how to run the first safe dry-run simulation.

# %%
import sys
sys.path.insert(0, "../src")

from multi_agent_safety_sim.config import load_config
from multi_agent_safety_sim.simulation.runner import SimulationRunner

cfg = load_config("../config.yaml")
print("Config loaded successfully. Safety max_steps =", cfg.safety.max_steps)
